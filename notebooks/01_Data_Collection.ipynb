# %% [markdown]
# # Data Collection
#
# Use this notebook to gather and inspect the raw Samsung product data.

# %%
import pandas as pd
import numpy as np

print("Environment Ready!")
# Out:
# Environment Ready!

# %%
df = pd.read_csv("../data/raw/SamsungPhoneData.csv")

df.head()
# Out:
#            Name               Dimensions  \
# 0  Ativ Odyssey     59 x 110.1 x 12.3 mm
# 1        Ativ S   63.1 x 121.5 x 10.5 mm
# 2    ATIV S Neo   61.3 x 124.6 x 8.94 mm
# 3       Ativ SE     186.9 x 107.9 x 9 mm
# 4      Ativ Tab   63.5 x 121.9 x 12.7 mm
#
#                                       SoC                      CPU  \
# 0              Samsung Exynos 4 Quad 4412        2x 1.5 GHz Krait,
# 1       Qualcomm Snapdragon S1 (MSM7225A)        2x 1.5 GHz Krait,
# 2        Qualcomm Snapdragon S2 (MSM8655)    2x 1.4 GHz Krait 300,
# 3       Qualcomm Snapdragon 400 (MSM8226)   4x 2.26 GHz Krait 400,
# 4   Qualcomm Snapdragon S4 Plus (MSM8960)        2x 1.5 GHz Krait,
#
#                              GPU               RAM       Storage  \
# 0          Broadcom VideoCore IV     1 GB, 400 MHz          8 GB
# 1   Qualcomm Adreno 225, 400 MHz   768 MB, 333 MHz          4 GB
# 2               ARM Mali-400 MP4   1.5 GB, 400 MHz          8 GB
# ...

# %%
print("Shape :", df.shape)
print("\nColumns:\n")
print(df.columns)
# Out:
# Shape : (720, 11)
#
# Columns:
#
# Index(['Name', 'Dimensions', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Display',
#        'Battery', 'OS', 'Camera'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        720 non-null    str
#  1   Dimensions  720 non-null    str
#  2   SoC         720 non-null    str
#  3   CPU         720 non-null    str
#  4   GPU         720 non-null    str
#  5   RAM         720 non-null    str
#  6   Storage     720 non-null    str
#  7   Display     720 non-null    str
#  8   Battery     720 non-null    str
#  9   OS          720 non-null    str
#  10  Camera      720 non-null    str
# dtypes: str(11)
# memory usage: 62.0 KB

# %%
df.isnull().sum()
# Out:
# Name          0
# Dimensions    0
# SoC           0
# CPU           0
# GPU           0
# RAM           0
# Storage       0
# Display       0
# Battery       0
# OS            0
# Camera        0
# dtype: int64

# %%
print("Duplicates :", df.duplicated().sum())
# Out:
# Duplicates : 0
