# %% [markdown]
# # Dataset Expansion
#
# This notebook expands the original Kaggle Samsung smartphone dataset by incorporating the latest Samsung smartphones launched in 2024 and 2025.
#
# The expanded dataset introduces additional machine learning-friendly features while preserving the original dataset.
#
# Output:
# - SamsungPhoneData_Updated.csv

# %%
import pandas as pd

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %%
df = pd.read_csv("../data/interim/SamsungPhoneData_Updated.csv")

print("Merged Dataset Shape:", df.shape)
# Out:
# Merged Dataset Shape: (749, 21)

# %%
df.head()
# Out:
#            Name               Dimensions  \
# 0  Ativ Odyssey     59 x 110.1 x 12.3 mm
# 1        Ativ S   63.1 x 121.5 x 10.5 mm
# 2    ATIV S Neo   61.3 x 124.6 x 8.94 mm
# 3       Ativ SE     186.9 x 107.9 x 9 mm
# 4      Ativ Tab   63.5 x 121.9 x 12.7 mm
#
#                                       SoC                      CPU  \
# 0              Samsung Exynos 4 Quad 4412        2x 1.5 GHz Krait,
# 1       Qualcomm Snapdragon S1 (MSM7225A)        2x 1.5 GHz Krait,
# 2        Qualcomm Snapdragon S2 (MSM8655)    2x 1.4 GHz Krait 300,
# 3       Qualcomm Snapdragon 400 (MSM8226)   4x 2.26 GHz Krait 400,
# 4   Qualcomm Snapdragon S4 Plus (MSM8960)        2x 1.5 GHz Krait,
#
#                              GPU               RAM       Storage  \
# 0          Broadcom VideoCore IV     1 GB, 400 MHz          8 GB
# 1   Qualcomm Adreno 225, 400 MHz   768 MB, 333 MHz          4 GB
# 2               ARM Mali-400 MP4   1.5 GB, 400 MHz          8 GB
# ...

# %%
df.tail(30)
# Out:
#                    Name              Dimensions  \
# 719                  Z4   73.4 x 159.5 x 8.1 mm
# 720       Galaxy A15 5G                     NaN
# 721       Galaxy A16 5G                     NaN
# 722       Galaxy A25 5G                     NaN
# 723       Galaxy A26 5G                     NaN
# 724       Galaxy A35 5G                     NaN
# 725       Galaxy A36 5G                     NaN
# 726       Galaxy A55 5G                     NaN
# 727       Galaxy A56 5G                     NaN
# 728       Galaxy M15 5G                     NaN
# 729       Galaxy M35 5G                     NaN
# 730       Galaxy M36 5G                     NaN
# 731       Galaxy M56 5G                     NaN
# 732       Galaxy F15 5G                     NaN
# 733       Galaxy F35 5G                     NaN
# 734       Galaxy F55 5G                     NaN
# 735       Galaxy F56 5G                     NaN
# 736       Galaxy S24 FE                     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 749 entries, 0 to 748
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             749 non-null    str
#  1   Dimensions       720 non-null    str
#  2   SoC              749 non-null    str
#  3   CPU              749 non-null    str
#  4   GPU              720 non-null    str
#  5   RAM              749 non-null    str
#  6   Storage          749 non-null    str
#  7   Display          720 non-null    str
#  8   Battery          749 non-null    str
#  9   OS               749 non-null    str
#  10  Camera           720 non-null    str
#  11  Launch_Year      29 non-null     float64
#  12  Series           749 non-null    str
#  13  Main_Camera_MP   749 non-null    int64
#  14  UltraWide_MP     28 non-null     float64
#  15  Telephoto_MP     9 non-null      float64
#  16  Front_Camera_MP  29 non-null     float64
# ...

# %%
df.isnull().sum()
# Out:
# Name                 0
# Dimensions          29
# SoC                  0
# CPU                  0
# GPU                 29
# RAM                  0
# Storage              0
# Display             29
# Battery              0
# OS                   0
# Camera              29
# Launch_Year        720
# Series               0
# Main_Camera_MP       0
# UltraWide_MP       721
# Telephoto_MP       740
# Front_Camera_MP    720
# OIS                  0
# AI_Features          0
# Waterproof           0
# Target_Segment       0
# dtype: int64

# %%
print("Merged Dataset Shape:", df.shape)

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Merged Dataset Shape: (749, 21)
#
# Missing Values:
# Name                 0
# Dimensions          29
# SoC                  0
# CPU                  0
# GPU                 29
# RAM                  0
# Storage              0
# Display             29
# Battery              0
# OS                   0
# Camera              29
# Launch_Year        720
# Series               0
# Main_Camera_MP       0
# UltraWide_MP       721
# Telephoto_MP       740
# Front_Camera_MP    720
# OIS                  0
# AI_Features          0
# Waterproof           0
# Target_Segment       0
# dtype: int64

# %% [markdown]
# ### Observations
#
# - The merged dataset contains both the original Kaggle records and the latest Samsung devices.
# - New structured features have been added.
# - Missing values are expected due to differences in schema between the original and appended datasets.
# - Missing values will be handled systematically in the Data Cleaning stage.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
